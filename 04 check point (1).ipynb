# %%
# 1. Explorez cet ensemble de données en utilisant ce que vous avez appris
# dans le prétraitementet la visualisation des données 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
from sklearn.model_selection import train_test_split
# Séparation des variables d'entrée (X) et cible (y)
X = df.drop("date", axis=1)
y = df["date"]
df=pd.read_csv("kc_house_data.csv",sep=",")
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [68], in <cell line: 10>()
#       8 from sklearn.model_selection import train_test_split
#       9 # Séparation des variables d'entrée (X) et cible (y)
# ---> 10 X = df.drop("date", axis=1)
#      11 y = df["date"]
#      12 df=pd.read_csv("kc_house_data.csv",sep=",")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
## les infos manquantes 

import pandas as pd
df=pd.read_csv("kc_house_data.csv",sep=";")
df.isnull().sum().sum()

# %%
## Phase de visualisation
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
 plot_correlation_map( df )

# %%
# Division du jeu de données en entraînement (80%) et test (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# 4. Appliquez une régression linéaire à votre ensemble d’entraînement.
df["date"].replace(["?","NA"], np.nan, inplace=True)
df["date"].fillna(df["date"].mean(), inplace=True)
df["date"] = df["date"].astype(float)
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Évaluer le modèle sur les données de test
score = model.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [69], in <cell line: 2>()
#       1 # Évaluer le modèle sur les données de test
# ----> 2 score = model.score(X_test, y_test)
#
# NameError: name 'model' is not defined
